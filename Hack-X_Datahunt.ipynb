# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Y = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\targets.csv")
Y.head()
# Out:
#    Green Frogs  Brown Frogs  Common Toad  Fire-Bellied Toad  Tree Frog  \
# 0            0            0            0                  0          0
# 1            0            1            1                  0          0
# 2            0            1            1                  0          0
# 3            0            0            1                  0          0
# 4            0            1            1                  1          0
#
#    Common Newt  Great Crested Newt
# 0            0                   0
# 1            1                   0
# 2            1                   0
# 3            0                   0
# 4            1                   1

# %%
Y.shape
# Out:
# (196, 7)

# %%
df0=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_0.csv")
df2=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_2.csv")
df4=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_4.csv")
df6=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_6.csv")
df8=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_8.csv")
df10=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_10.csv")
df12=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_12.csv")
df14=df = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Features_14.csv")
df_half = pd.read_csv("C:\\Users\\manig\\Downloads\\Datahunt\\Half Data Frame.csv")

# %%
frames = [df0, df2, df4, df6, df8, df10, df12, df14]
df = pd.concat(frames, axis=1)
df
# Out:
#     ID Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR  \
# 0    1       A1      82.122666  1.0   1   4   6.0     2    10  0.0  0
# 1    2       A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  1
# 2    3       A1    1193.589181  1.0   5   1   NaN     6    10  3.0  4
# 3    4       A1     629.864146  1.0   5   0   6.0    10     2  3.0  4
# 4    5       A1 -180803.798800  2.0   1   4   NaN     2     6  0.0  0
# ..  ..      ...            ...  ...  ..  ..   ...   ...   ...  ... ..
# 92  93      S52    4583.001126  1.0   1   3   NaN     1     2  0.0  0
# 93  94      S52     -27.508706  1.0  15   1   1.0     7     2  0.0  0
# 94  95      S52    4794.131353  1.0   1   0   NaN    10     2  3.0  2
# 95  96      S52   11967.210990  1.0   1   3   1.0    10     6  NaN  1
# 96  97      S52   -2568.296384  4.0   1   0   NaN     2     6  0.0  1
#
#             OR   RR  BR MR   CR
# 0    50.000000  0.0   0  0  NaN
# 1    75.000000  1.0   1  0  1.0
# ...

# %%
df = pd.concat([df, df_half], ignore_index=True)
df
# Out:
#       ID Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR  \
# 0      1       A1      82.122666  1.0   1   4   6.0     2    10  0.0  0
# 1      2       A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  1
# 2      3       A1    1193.589181  1.0   5   1   NaN     6    10  3.0  4
# 3      4       A1     629.864146  1.0   5   0   6.0    10     2  3.0  4
# 4      5       A1 -180803.798800  2.0   1   4   NaN     2     6  0.0  0
# ..   ...      ...            ...  ...  ..  ..   ...   ...   ...  ... ..
# 191  192      S52  115998.517900  9.0   1   3   2.0     9     6  3.0  4
# 192  193       A1     164.442663  1.0  14   2   1.0     2     7  0.0  0
# 193  194      S52    -866.209002  1.0  12   2  10.0    10     2  0.0  0
# 194  195      S52   27369.210340  3.0   1   2  10.0     6     1  3.0  3
# 195  196      S52     889.098487  1.0   1   4   9.0     2    10  0.0  0
#
#         OR   RR  BR MR   CR
# 0     50.0  0.0   0  0  NaN
# 1     75.0  1.0   1  0  1.0
# ...

# %%
df = pd.concat([df, Y], axis=1)
df
# Out:
#       ID Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR  ... BR  \
# 0      1       A1      82.122666  1.0   1   4   6.0     2    10  0.0  ...  0
# 1      2       A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  ...  1
# 2      3       A1    1193.589181  1.0   5   1   NaN     6    10  3.0  ...  1
# 3      4       A1     629.864146  1.0   5   0   6.0    10     2  3.0  ...  0
# 4      5       A1 -180803.798800  2.0   1   4   NaN     2     6  0.0  ...  5
# ..   ...      ...            ...  ...  ..  ..   ...   ...   ...  ...  ... ..
# 191  192      S52  115998.517900  9.0   1   3   2.0     9     6  3.0  ...  0
# 192  193       A1     164.442663  1.0  14   2   1.0     2     7  0.0  ...  1
# 193  194      S52    -866.209002  1.0  12   2  10.0    10     2  0.0  ...  5
# 194  195      S52   27369.210340  3.0   1   2  10.0     6     1  3.0  ...  0
# 195  196      S52     889.098487  1.0   1   4   9.0     2    10  0.0  ...  0
#
# ...

# %%
df.drop(['ID'], axis=1, inplace=True)
df
# Out:
#     Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR  ...  BR  \
# 0         A1      82.122666  1.0   1   4   6.0     2    10  0.0  0  ...   0
# 1         A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  1  ...   1
# 2         A1    1193.589181  1.0   5   1   NaN     6    10  3.0  4  ...   1
# 3         A1     629.864146  1.0   5   0   6.0    10     2  3.0  4  ...   0
# 4         A1 -180803.798800  2.0   1   4   NaN     2     6  0.0  0  ...   5
# ..       ...            ...  ...  ..  ..   ...   ...   ...  ... ..  ...  ..
# 191      S52  115998.517900  9.0   1   3   2.0     9     6  3.0  4  ...   0
# 192       A1     164.442663  1.0  14   2   1.0     2     7  0.0  0  ...   1
# 193      S52    -866.209002  1.0  12   2  10.0    10     2  0.0  0  ...   5
# 194      S52   27369.210340  3.0   1   2  10.0     6     1  3.0  3  ...   0
# 195      S52     889.098487  1.0   1   4   9.0     2    10  0.0  0  ...   0
#
# ...

# %%
colNames = []
for col in df.columns:
    colNames.append(col)
    
for i in colNames:
    df[i]=df[i].apply(lambda x: np.nan if x=='?' else x)
df
# Out:
#     Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR  ...  BR  \
# 0         A1      82.122666  1.0   1   4   6.0     2    10  0.0  0  ...   0
# 1         A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  1  ...   1
# 2         A1    1193.589181  1.0   5   1   NaN     6    10  3.0  4  ...   1
# 3         A1     629.864146  1.0   5   0   6.0    10     2  3.0  4  ...   0
# 4         A1 -180803.798800  2.0   1   4   NaN     2     6  0.0  0  ...   5
# ..       ...            ...  ...  ..  ..   ...   ...   ...  ... ..  ...  ..
# 191      S52  115998.517900  9.0   1   3   2.0     9     6  3.0  4  ...   0
# 192       A1     164.442663  1.0  14   2   1.0     2     7  0.0  0  ...   1
# 193      S52    -866.209002  1.0  12   2  10.0    10     2  0.0  0  ...   5
# 194      S52   27369.210340  3.0   1   2  10.0     6     1  3.0  3  ...   0
# 195      S52     889.098487  1.0   1   4   9.0     2    10  0.0  0  ...   0
#
# ...

# %%
df.isnull().sum()
# Out:
# Motorway               0
# SR                     0
# NR                     0
# TR                    18
# VR                     0
# SUR1                  94
# SUR2                   0
# SUR3                   0
# UR                    37
# FR                    12
# OR                     0
# RR                    31
# BR                     0
# MR                    25
# CR                    20
# Green Frogs            0
# Brown Frogs            0
# Common Toad            0
# Fire-Bellied Toad      0
# Tree Frog              0
# Common Newt            0
# Great Crested Newt     0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.groupby('CR').describe()
# Out:
#         SR                                                                     \
#      count          mean            std          min         25%          50%
# CR
# 1.0  170.0  -5459.493833   71324.355516 -181624.9900 -372.853613   688.240250
# 2.0    6.0  43067.824284  277118.376049 -361500.2032   -0.282953  1517.532054
#
#                                    NR            ... Common Newt       \
#               75%          max  count      mean  ...         75%  max
# CR                                               ...
# 1.0   2303.098866  500955.1734  170.0  1.248873  ...         1.0  1.0
# 2.0  87696.732526  500955.1734    6.0  3.000000  ...         0.0  1.0
#
#     Great Crested Newt
#                  count      mean       std  min  25%  50%   75%  max
# CR
# 1.0              170.0  0.111765  0.316008  0.0  0.0  0.0  0.00  1.0
# 2.0                6.0  0.500000  0.836660  0.0  0.0  0.0  0.75  2.0
#
# [2 rows x 136 columns]

# %%
df['SUR1'].fillna(df['SUR1'].mode()[0], inplace=True)

# %%
df.drop(columns=['RR'],inplace=True)

# %%
df
# Out:
#     Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR  ...  BR  \
# 0         A1      82.122666  1.0   1   4   6.0     2    10  0.0  0  ...   0
# 1         A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  1  ...   1
# 2         A1    1193.589181  1.0   5   1   2.0     6    10  3.0  4  ...   1
# 3         A1     629.864146  1.0   5   0   6.0    10     2  3.0  4  ...   0
# 4         A1 -180803.798800  2.0   1   4   2.0     2     6  0.0  0  ...   5
# ..       ...            ...  ...  ..  ..   ...   ...   ...  ... ..  ...  ..
# 191      S52  115998.517900  9.0   1   3   2.0     9     6  3.0  4  ...   0
# 192       A1     164.442663  1.0  14   2   1.0     2     7  0.0  0  ...   1
# 193      S52    -866.209002  1.0  12   2  10.0    10     2  0.0  0  ...   5
# 194      S52   27369.210340  3.0   1   2  10.0     6     1  3.0  3  ...   0
# 195      S52     889.098487  1.0   1   4   9.0     2    10  0.0  0  ...   0
#
# ...

# %%
df['MR'].fillna(df['MR'].mode()[0], inplace=True)
df['UR'].fillna(df['UR'].mode()[0], inplace=True)
df['FR'].fillna(df['FR'].mode()[0], inplace=True)
df['TR'].fillna(df['TR'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Motorway               0
# SR                     0
# NR                     0
# TR                     0
# VR                     0
# SUR1                   0
# SUR2                   0
# SUR3                   0
# UR                     0
# FR                     0
# OR                     0
# BR                     0
# MR                     0
# CR                    20
# Green Frogs            0
# Brown Frogs            0
# Common Toad            0
# Fire-Bellied Toad      0
# Tree Frog              0
# Common Newt            0
# Great Crested Newt     0
# dtype: int64

# %%
df['CR'].fillna(df['CR'].mode()[0], inplace=True)

# %%
df.groupby('CR').describe()
# Out:
#         SR                                                                     \
#      count          mean            std          min         25%          50%
# CR
# 1.0  190.0  -4009.437036   67696.706606 -181624.9900 -295.548111   756.289927
# 2.0    6.0  43067.824284  277118.376049 -361500.2032   -0.282953  1517.532054
#
#                                    NR            ... Common Newt       \
#               75%          max  count      mean  ...         75%  max
# CR                                               ...
# 1.0   2431.342797  500955.1734  190.0  1.264781  ...         1.0  1.0
# 2.0  87696.732526  500955.1734    6.0  3.000000  ...         0.0  1.0
#
#     Great Crested Newt
#                  count      mean       std  min  25%  50%   75%  max
# CR
# 1.0              190.0  0.115789  0.320818  0.0  0.0  0.0  0.00  1.0
# 2.0                6.0  0.500000  0.836660  0.0  0.0  0.0  0.75  2.0
#
# [2 rows x 128 columns]

# %%
df.drop(columns=['CR'], axis=1, inplace=True)

# %%
df
# Out:
#     Motorway             SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  BR  \
# 0         A1      82.122666  1.0   1   4   6.0     2    10  0.0  0   50.0   0
# 1         A1 -180534.465700  1.0   5   1  10.0     6    10  3.0  1   75.0   1
# 2         A1    1193.589181  1.0   5   1   2.0     6    10  3.0  4   75.0   1
# 3         A1     629.864146  1.0   5   0   6.0    10     2  3.0  4   25.0   0
# 4         A1 -180803.798800  2.0   1   4   2.0     2     6  0.0  0   99.0   5
# ..       ...            ...  ...  ..  ..   ...   ...   ...  ... ..    ...  ..
# 191      S52  115998.517900  9.0   1   3   2.0     9     6  3.0  4   75.0   0
# 192       A1     164.442663  1.0  14   2   1.0     2     7  0.0  0  100.0   1
# 193      S52    -866.209002  1.0  12   2  10.0    10     2  0.0  0   50.0   5
# 194      S52   27369.210340  3.0   1   2  10.0     6     1  3.0  3  100.0   0
# 195      S52     889.098487  1.0   1   4   9.0     2    10  0.0  0   50.0   0
#
# ...

# %%
df['SR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler
df['SR'] = MinMaxScaler().fit_transform(np.array(df['SR']).reshape(-1,1))
df
# Out:
#     Motorway        SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  BR MR  \
# 0         A1  0.419248  1.0   1   4   6.0     2    10  0.0  0   50.0   0  0
# 1         A1  0.209826  1.0   5   1  10.0     6    10  3.0  1   75.0   1  0
# 2         A1  0.420536  1.0   5   1   2.0     6    10  3.0  4   75.0   1  0
# 3         A1  0.419883  1.0   5   0   6.0    10     2  3.0  4   25.0   0  0
# 4         A1  0.209514  2.0   1   4   2.0     2     6  0.0  0   99.0   5  0
# ..       ...       ...  ...  ..  ..   ...   ...   ...  ... ..    ...  .. ..
# 191      S52  0.553650  9.0   1   3   2.0     9     6  3.0  4   75.0   0  0
# 192       A1  0.419343  1.0  14   2   1.0     2     7  0.0  0  100.0   1  0
# 193      S52  0.418148  1.0  12   2  10.0    10     2  0.0  0   50.0   5  0
# 194      S52  0.450886  3.0   1   2  10.0     6     1  3.0  3  100.0   0  0
# 195      S52  0.420183  1.0   1   4   9.0     2    10  0.0  0   50.0   0  0
#
# ...

# %%
df['SR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
Q1 = df.SR.quantile(0.25)
Q3 = df.SR.quantile(0.75)
Q1, Q3
# Out:
# (0.41883550769436984, 0.4224378547995592)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.003602347105189363

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (0.4134319870365858, 0.42784137545734324)

# %%
df[(df.SR<lower_limit)|(df.SR>upper_limit)]
# Out:
#     Motorway        SR        NR  TR  VR  SUR1  SUR2  SUR3   UR FR  \
# 1         A1  0.209826   1.00000   5   1  10.0     6    10  3.0  1
# 4         A1  0.209514   2.00000   1   4   2.0     2     6  0.0  0
# 10        A1  0.210898   1.00000   1   4   2.0     7     1  0.0  0
# 14        A1  0.427916   1.00000   1   3   2.0    10     7  0.0  0
# 15        A1  0.453182   1.00000   1   3   1.0     1     1  0.0  0
# 28        A1  0.454434   1.00000   1   3   2.0     2     1  1.0  0
# 40        A1  0.512115   1.00000   1   4   2.0     2     7  0.0  0
# 44        A1  0.453244   6.00000   1   0   2.0     7     6  3.0  4
# 45        A1  0.211275   1.00000  12   4   2.0     7     2  0.0  0
# 46        A1  0.449874   5.00000   1   0   2.0     9     7  3.0  4
# 47        A1  0.467748   1.00000   1   1   2.0     2     6  3.0  2
# 49        A1  0.210839  -3.89097   1   2   2.0     7     6  0.0  0
# 51        A1  0.215575   1.00000   1   3   1.0     1     2  0.0  0
# ...

# %%
df = df[(df.SR>lower_limit)&(df.SR<upper_limit)]
df
# Out:
#     Motorway        SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR          OR  BR  \
# 0         A1  0.419248  1.0   1   4   6.0     2    10  0.0  0   50.000000   0
# 2         A1  0.420536  1.0   5   1   2.0     6    10  3.0  4   75.000000   1
# 3         A1  0.419883  1.0   5   0   6.0    10     2  3.0  4   25.000000   0
# 5         A1  0.420754  1.0   5   1   6.0     6    10  0.0  0   50.000000   0
# 6         A1  0.419435  1.0   5   0   2.0     6    10  1.0  2  -33.680241   0
# ..       ...       ...  ...  ..  ..   ...   ...   ...  ... ..         ...  ..
# 188      S52  0.420136  1.0  12   3   2.0     6    10  0.0  0  217.360481   1
# 190      S52  0.419058  1.0   1   0  10.0     6     1  0.0  4   50.000000   1
# 192       A1  0.419343  1.0  14   2   1.0     2     7  0.0  0  100.000000   1
# 193      S52  0.418148  1.0  12   2  10.0    10     2  0.0  0   50.000000   5
# 195      S52  0.420183  1.0   1   4   9.0     2    10  0.0  0   50.000000   0
#
# ...

# %%
df['SR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['OR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
Q1 = df.OR.quantile(0.25)
Q3 = df.OR.quantile(0.75)
Q1, Q3
# Out:
# (80.0, 100.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 20.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (50.0, 130.0)

# %%
df[(df.OR<lower_limit)|(df.OR>upper_limit)]
# Out:
#     Motorway        SR       NR  TR  VR  SUR1  SUR2  SUR3   UR FR          OR  \
# 3         A1  0.419883  1.00000   5   0   6.0    10     2  3.0  4   25.000000
# 6         A1  0.419435  1.00000   5   0   2.0     6    10  1.0  2  -33.680241
# 12        A1  0.416174  1.00000   1   1   2.0     6    10  3.0  3   -8.680241
# 27        A1  0.426904  1.00000   1   4   2.0     2     1  0.0  0  158.680240
# 39        A1  0.418427  1.00000   5   1   7.0     2     6  3.0  0  158.680240
# 64        A1  0.421889  1.00000   2   0   2.0     9     2  0.0  0   -8.680241
# 94       S52  0.424711  1.00000   1   0   2.0    10     2  3.0  2  158.680240
# 96       S52  0.416174  4.00000   1   0   2.0     2     6  0.0  1   16.319759
# 105      S52  0.419503 -3.89097   1   1   6.0    10    10  0.0  0   25.000000
# 118      S52  0.419456 -3.89097   1   1   2.0    10    10  3.0  3  158.680240
# 119      S52  0.421152  1.00000  15   1   1.0    10     6  0.0  0  158.680240
# ...

# %%
df = df[(df.OR>lower_limit)&(df.OR<upper_limit)]
df
# Out:
#     Motorway        SR   NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  BR MR  \
# 2         A1  0.420536  1.0   5   1   2.0     6    10  3.0  4   75.0   1  0
# 7         A1  0.420397  1.0   5   2  10.0     6     9  0.0  0  100.0   1  0
# 9         A1  0.419257  1.0  12   4   2.0     7     6  0.0  0   75.0   0  0
# 11        A1  0.419343  1.0  14   2   1.0     2     7  0.0  0  100.0   1  0
# 13        A1  0.420931  1.0   1   1   2.0     6    10  0.0  1  100.0   2  2
# ..       ...       ...  ...  ..  ..   ...   ...   ...  ... ..    ...  .. ..
# 183      S52  0.423223  1.0  12   4   2.0     6    10  0.0  0  100.0   1  0
# 185      S52  0.418910  1.0  14   2   7.0    10     2  0.0  0  100.0   5  0
# 186      S52  0.418938  1.0   1   4   2.0    10     2  0.0  0  100.0   5  0
# 187      S52  0.418786  1.0  12   3   2.0     1     6  0.0  0  100.0   0  0
# 192       A1  0.419343  1.0  14   2   1.0     2     7  0.0  0  100.0   1  0
#
# ...

# %%
df['OR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['NR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['NR'] = MinMaxScaler().fit_transform(np.array(df['NR']).reshape(-1,1))
df
# Out:
# C:\Users\manig\AppData\Local\Temp\ipykernel_3956\981767197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NR'] = MinMaxScaler().fit_transform(np.array(df['NR']).reshape(-1,1))
#     Motorway        SR        NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  BR  \
# 2         A1  0.420536  0.619819   5   1   2.0     6    10  3.0  4   75.0   1
# 7         A1  0.420397  0.619819   5   2  10.0     6     9  0.0  0  100.0   1
# 9         A1  0.419257  0.619819  12   4   2.0     7     6  0.0  0   75.0   0
# 11        A1  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0   1
# 13        A1  0.420931  0.619819   1   1   2.0     6    10  0.0  1  100.0   2
# ...

# %%
df['NR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df["TR"] = pd.to_numeric(df["TR"])
# Out:
# C:\Users\manig\AppData\Local\Temp\ipykernel_3956\3836637503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TR"] = pd.to_numeric(df["TR"])

# %%
df
# Out:
#     Motorway        SR        NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  BR  \
# 2         A1  0.420536  0.619819   5   1   2.0     6    10  3.0  4   75.0   1
# 7         A1  0.420397  0.619819   5   2  10.0     6     9  0.0  0  100.0   1
# 9         A1  0.419257  0.619819  12   4   2.0     7     6  0.0  0   75.0   0
# 11        A1  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0   1
# 13        A1  0.420931  0.619819   1   1   2.0     6    10  0.0  1  100.0   2
# ..       ...       ...       ...  ..  ..   ...   ...   ...  ... ..    ...  ..
# 183      S52  0.423223  0.619819  12   4   2.0     6    10  0.0  0  100.0   1
# 185      S52  0.418910  0.619819  14   2   7.0    10     2  0.0  0  100.0   5
# 186      S52  0.418938  0.619819   1   4   2.0    10     2  0.0  0  100.0   5
# 187      S52  0.418786  0.619819  12   3   2.0     1     6  0.0  0  100.0   0
# 192       A1  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0   1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 2 to 192
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Motorway            119 non-null    object
#  1   SR                  119 non-null    float64
#  2   NR                  119 non-null    float64
#  3   TR                  119 non-null    int64
#  4   VR                  119 non-null    int64
#  5   SUR1                119 non-null    float64
#  6   SUR2                119 non-null    int64
#  7   SUR3                119 non-null    int64
#  8   UR                  119 non-null    float64
#  9   FR                  119 non-null    object
#  10  OR                  119 non-null    float64
#  11  BR                  119 non-null    int64
#  12  MR                  119 non-null    object
#  13  Green Frogs         119 non-null    int64
#  14  Brown Frogs         119 non-null    int64
# ...

# %%
df['TR'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.Motorway = le.fit_transform(df.Motorway) 
df
# Out:
# C:\Users\manig\AppData\Local\Temp\ipykernel_3956\4145785890.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Motorway = le.fit_transform(df.Motorway)
#      Motorway        SR        NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  \
# 2           0  0.420536  0.619819   5   1   2.0     6    10  3.0  4   75.0
# 7           0  0.420397  0.619819   5   2  10.0     6     9  0.0  0  100.0
# 9           0  0.419257  0.619819  12   4   2.0     7     6  0.0  0   75.0
# 11          0  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0
# 13          0  0.420931  0.619819   1   1   2.0     6    10  0.0  1  100.0
# ..        ...       ...       ...  ..  ..   ...   ...   ...  ... ..    ...
# ...

# %%
df.drop_duplicates()
# Out:
#      Motorway        SR        NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  \
# 2           0  0.420536  0.619819   5   1   2.0     6    10  3.0  4   75.0
# 7           0  0.420397  0.619819   5   2  10.0     6     9  0.0  0  100.0
# 9           0  0.419257  0.619819  12   4   2.0     7     6  0.0  0   75.0
# 11          0  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0
# 13          0  0.420931  0.619819   1   1   2.0     6    10  0.0  1  100.0
# ..        ...       ...       ...  ..  ..   ...   ...   ...  ... ..    ...
# 182         1  0.420465  0.619819   1   0   2.0     6    10  1.0  3  100.0
# 183         1  0.423223  0.619819  12   4   2.0     6    10  0.0  0  100.0
# 185         1  0.418910  0.619819  14   2   7.0    10     2  0.0  0  100.0
# 186         1  0.418938  0.619819   1   4   2.0    10     2  0.0  0  100.0
# 187         1  0.418786  0.619819  12   3   2.0     1     6  0.0  0  100.0
#
# ...

# %%
y = df[['Green Frogs','Brown Frogs','Common Toad','Fire-Bellied Toad','Tree Frog','Common Newt','Great Crested Newt']]

# %%
y
# Out:
#      Green Frogs  Brown Frogs  Common Toad  Fire-Bellied Toad  Tree Frog  \
# 2              0            1            1                  0          0
# 7              1            1            0                  1          0
# 9              0            1            1                  0          0
# 11             0            1            1                  0          0
# 13             1            1            1                  0          0
# ..           ...          ...          ...                ...        ...
# 183            0            1            1                  0          0
# 185            1            1            1                  1          0
# 186            1            1            1                  1          0
# 187            0            1            1                  0          0
# 192            0            1            1                  0          0
#
#      Common Newt  Great Crested Newt
# 2              1                   0
# ...

# %%
X
# Out:
#      Motorway        SR        NR  TR  VR  SUR1  SUR2  SUR3   UR FR     OR  \
# 2           0  0.420536  0.619819   5   1   2.0     6    10  3.0  4   75.0
# 7           0  0.420397  0.619819   5   2  10.0     6     9  0.0  0  100.0
# 9           0  0.419257  0.619819  12   4   2.0     7     6  0.0  0   75.0
# 11          0  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0
# 13          0  0.420931  0.619819   1   1   2.0     6    10  0.0  1  100.0
# ..        ...       ...       ...  ..  ..   ...   ...   ...  ... ..    ...
# 183         1  0.423223  0.619819  12   4   2.0     6    10  0.0  0  100.0
# 185         1  0.418910  0.619819  14   2   7.0    10     2  0.0  0  100.0
# 186         1  0.418938  0.619819   1   4   2.0    10     2  0.0  0  100.0
# 187         1  0.418786  0.619819  12   3   2.0     1     6  0.0  0  100.0
# 192         0  0.419343  0.619819  14   2   1.0     2     7  0.0  0  100.0
#
#      BR MR
# 2     1  0
# 7     1  0
# 9     0  0
# 11    1  0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
y1 = y_train['Green Frogs']
y2 = y_train['Brown Frogs']
y3 = y_train['Common Toad']
y4 = y_train['Fire-Bellied Toad']
y5 = y_train['Tree Frog']
y6 = y_train['Common Newt']
y7 = y_train['Great Crested Newt']

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [2, 3, 4, 5, 6, 8, 10, 20, 50],
            'kernel': ['rbf','linear', 'sigmoid', 'poly']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [10,50,100,200]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [0.1, 2, 4, 6, 8, 10]
        }
    }
}

# %%
from sklearn.model_selection import GridSearchCV

scores1 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y1)
    scores1.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc1 = pd.DataFrame(scores1,columns=['model','best_score','best_params'])
acc1
# Out:
#                  model  best_score                    best_params
# 0                  svm    0.800000  {'C': 50, 'kernel': 'linear'}
# 1        random_forest    0.715789          {'n_estimators': 100}
# 2  logistic_regression    0.747368                       {'C': 2}

# %%
scores2 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y2)
    scores2.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc2 = pd.DataFrame(scores2,columns=['model','best_score','best_params'])
acc2
# Out:
#                  model  best_score                    best_params
# 0                  svm    0.789474  {'C': 2, 'kernel': 'sigmoid'}
# 1        random_forest    0.768421           {'n_estimators': 10}
# 2  logistic_regression    0.768421                     {'C': 0.1}

# %%
scores3 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y3)
    scores3.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc3 = pd.DataFrame(scores3,columns=['model','best_score','best_params'])
acc3
# Out:
#                  model  best_score                best_params
# 0                  svm    0.694737  {'C': 8, 'kernel': 'rbf'}
# 1        random_forest    0.694737       {'n_estimators': 50}
# 2  logistic_regression    0.600000                 {'C': 0.1}

# %%
scores4 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y4)
    scores4.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc4 = pd.DataFrame(scores4,columns=['model','best_score','best_params'])
acc4
# Out:
#                  model  best_score                    best_params
# 0                  svm    0.757895  {'C': 2, 'kernel': 'sigmoid'}
# 1        random_forest    0.768421           {'n_estimators': 10}
# 2  logistic_regression    0.768421                     {'C': 0.1}

# %%
scores5 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y5)
    scores5.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc5 = pd.DataFrame(scores5,columns=['model','best_score','best_params'])
acc5
# Out:
#                  model  best_score                best_params
# 0                  svm    0.631579  {'C': 2, 'kernel': 'rbf'}
# 1        random_forest    0.589474       {'n_estimators': 10}
# 2  logistic_regression    0.589474                 {'C': 0.1}

# %%
scores6 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train,y6)
    scores6.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc6 = pd.DataFrame(scores6,columns=['model','best_score','best_params'])
acc6
# Out:
#                  model  best_score                   best_params
# 0                  svm    0.831579  {'C': 2, 'kernel': 'linear'}
# 1        random_forest    0.757895         {'n_estimators': 100}
# 2  logistic_regression    0.821053                      {'C': 2}

# %%
scores7 = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y7)
    scores7.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
acc7 = pd.DataFrame(scores7,columns=['model','best_score','best_params'])
acc7
# Out:
#                  model  best_score                    best_params
# 0                  svm    0.894737  {'C': 2, 'kernel': 'sigmoid'}
# 1        random_forest    0.894737           {'n_estimators': 50}
# 2  logistic_regression    0.915789                       {'C': 8}

# %% [markdown]
# Hack-X
# Column 1 Accuracy: 0.800000
# Column 2 Accuracy: 0.789474
# Column 3 Accuracy: 0.694737
# Column 4 Accuracy: 0.768421
# Column 5 Accuracy: 0.631579
# Column 6 Accuracy: 0.831579
# Column 7 Accuracy (Highest): 0.915789
# Cumulative Accuracy: 0.7759398
